# %%
#Importing the covid csv file provided in the USF Box

# File location and type
file_location = "/FileStore/tables/covid_19_clean_complete.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
# Reference:https://stackoverflow.com/questions/44296484/how-to-replace-null-nan-or-infinite-values-to-default-value-in-spark-scala
# Reference:https://stackoverflow.com/questions/46439410/spark-treating-null-values-in-csv-column-as-null-datatype
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .option('nanValue',' ')\
  .option('nulValue',' ')\
  .load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a temp table for running queries

temp_table_name = "covid"

df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Testing if the table creation is working fine
spark.sql("select * from covid limit 5").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-----------+--------+-------+---------+---------+------+---------+----------+
# province|    country|     lat|   long|     date|confirmed|deaths|recovered|  date_mod|
# +--------+-----------+--------+-------+---------+---------+------+---------+----------+
#     null|Afghanistan|    33.0|   65.0|1/22/2020|        0|     0|        0|2020-01-22|
#     null|    Albania| 41.1533|20.1683|1/22/2020|        0|     0|        0|2020-01-22|
#     null|    Algeria| 28.0339| 1.6596|1/22/2020|        0|     0|        0|2020-01-22|
#     null|    Andorra| 42.5063| 1.5218|1/22/2020|        0|     0|        0|2020-01-22|
#     null|     Angola|-11.2027|17.8739|1/22/2020|        0|     0|        0|2020-01-22|
# +--------+-----------+--------+-------+---------+---------+------+---------+----------+
#
# </div>

# %%
# Import function to convert date column into timestamp type
from pyspark.sql.functions import datediff,date_format,to_date,to_timestamp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a new column called date_mod of timestamp type in format that we desire
df = df.withColumn('date_mod', to_date(df.date, 'MM/dd/yy'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Since this is time series data, keeping only the latest observation for all countries as this represents the most recent reading 
df_new = df.filter("date_mod == '2020-04-30'")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create a new column in the dataframe to calculate percentage
df_new = df_new.withColumn("percentage", (F.col("deaths")/F.col("confirmed"))*100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a view or table

temp_table_name = "q1"

df_new.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("select country, percentage from q1 order by percentage desc limit 1").show()

#The country with the highest death rate is Yemen
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+
# country|       percentage|
# +-------+-----------------+
#   Yemen|33.33333333333333|
# +-------+-----------------+
#
# </div>

# %%
# Create new dataframe for this question's computations
df_month = df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Import split function
from pyspark.sql.functions import split
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Split the date-mod column and take the value of month alone. Store month in a separate column
split_col = split(df_month['date_mod'], '-')
df_month = df.withColumn('month', split_col.getItem(1))
display(df_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>province</th><th>country</th><th>lat</th><th>long</th><th>date</th><th>confirmed</th><th>deaths</th><th>recovered</th><th>date_mod</th><th>month</th></tr></thead><tbody><tr><td>null</td><td>Afghanistan</td><td>33.0</td><td>65.0</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Albania</td><td>41.1533</td><td>20.1683</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Algeria</td><td>28.0339</td><td>1.6596</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Andorra</td><td>42.5063</td><td>1.5218</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Angola</td><td>-11.2027</td><td>17.8739</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Antigua and Barbuda</td><td>17.0608</td><td>-61.7964</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Argentina</td><td>-38.4161</td><td>-63.6167</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Armenia</td><td>40.0691</td><td>45.0382</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>Australian Capital Territory</td><td>Australia</td><td>-35.4735</td><td>149.0124</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>New South Wales</td><td>Australia</td><td>-33.8688</td><td>151.2093</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>Northern Territory</td><td>Australia</td><td>-12.4634</td><td>130.8456</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>Queensland</td><td>Australia</td><td>-28.0167</td><td>153.4</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>South Australia</td><td>Australia</td><td>-34.9285</td><td>138.6007</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>Tasmania</td><td>Australia</td><td>-41.4545</td><td>145.9707</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>Victoria</td><td>Australia</td><td>-37.8136</td><td>144.9631</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>Western Australia</td><td>Australia</td><td>-31.9505</td><td>115.8605</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Austria</td><td>47.5162</td><td>14.5501</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Azerbaijan</td><td>40.1431</td><td>47.5769</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Bahamas</td><td>25.0343</td><td>-77.3963</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Bahrain</td><td>26.0275</td><td>50.55</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Bangladesh</td><td>23.685</td><td>90.3563</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Barbados</td><td>13.1939</td><td>-59.5432</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Belarus</td><td>53.7098</td><td>27.9534</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Belgium</td><td>50.8333</td><td>4.0</td><td>1/22/2020</td><td>0</td><td>0</td><td>0</td><td>2020-01-22</td><td>01</td></tr><tr><td>null</td><td>Benin</t ...

# %%
#Create new dataframes for various months and filtering only the last day of the month since it represents the final reading for the month
df_jan = df_month.filter("date_mod == '2020-01-31'")
df_feb = df_month.filter("date_mod == '2020-02-29'")
df_march = df_month.filter("date_mod == '2020-03-31'")
df_apr = df_month.filter("date_mod == '2020-04-30'")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create a new column in the dataframes to calculate percentage
df_jan = df_jan.withColumn("percentage", (F.col("deaths")/F.col("confirmed"))*100)
df_feb = df_feb.withColumn("percentage", (F.col("deaths")/F.col("confirmed"))*100)
df_march = df_march.withColumn("percentage", (F.col("deaths")/F.col("confirmed"))*100)
df_apr = df_apr.withColumn("percentage", (F.col("deaths")/F.col("confirmed"))*100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create tables for all the above dataframes
temp_table_name = "jan"
df_jan.createOrReplaceTempView(temp_table_name)

temp_table_name = "feb"
df_feb.createOrReplaceTempView(temp_table_name)

temp_table_name = "march"
df_march.createOrReplaceTempView(temp_table_name)

temp_table_name = "april"
df_apr.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("select country, month, percentage from jan order by percentage desc limit 1").show()
spark.sql("select country, month, percentage from feb order by percentage desc limit 1").show()
spark.sql("select country, month, percentage from march order by percentage desc limit 1").show()
spark.sql("select country, month, percentage from april order by percentage desc limit 1").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+-----------------+
# country|month|       percentage|
# +-------+-----+-----------------+
#   China|   01|3.513606613847744|
# +-------+-----+-----------------+
#
# +-----------+-----+-----------------+
#     country|month|       percentage|
# +-----------+-----+-----------------+
# Philippines|   02|33.33333333333333|
# +-----------+-----+-----------------+
#
# +-------+-----+-----------------+
# country|month|       percentage|
# +-------+-----+-----------------+
#  Angola|   03|28.57142857142857|
# +-------+-----+-----------------+
#
# +-------+-----+-----------------+
# country|month|       percentage|
# +-------+-----+-----------------+
#   Yemen|   04|33.33333333333333|
# +-------+-----+-----------------+
#
# </div>

# %%
#Use the following data set to identify which country belongs to which continent.   

#https://github.com/dbouquin/IS_608/blob/master/NanosatDB_munging/Countries-Continents.csv (Links to an external site.)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Load the continents CSV

# File location and type
file_location = "/FileStore/tables/continentmapping.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
# Reference:https://stackoverflow.com/questions/44296484/how-to-replace-null-nan-or-infinite-values-to-default-value-in-spark-scala
# Reference:https://stackoverflow.com/questions/46439410/spark-treating-null-values-in-csv-column-as-null-datatype
contdf = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .option('nanValue',' ')\
  .option('nulValue',' ')\
  .load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a view or table

temp_table_name = "conts"

contdf.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create a new dataframe using join on Continents table & original COVID table
mapped_df = spark.sql("select * from covid full outer join conts on covid.country = conts.Country")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Filter only records representing Asia continent
asia = mapped_df.filter("Continent == 'Asia'")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create new dataframes for various months and filtering only the last day of the month since it represents the final reading for the month
asia_jan = asia.filter("date_mod == '2020-01-31'")
asia_feb = asia.filter("date_mod == '2020-02-29'")
asia_mar = asia.filter("date_mod == '2020-03-31'")
asia_apr = asia.filter("date_mod == '2020-04-30'")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
split_col = split(asia['date_mod'], '-')
asia_jan = asia_jan.withColumn('month', split_col.getItem(1))
asia_feb = asia_feb.withColumn('month', split_col.getItem(1))
asia_mar = asia_mar.withColumn('month', split_col.getItem(1))
asia_apr = asia_apr.withColumn('month', split_col.getItem(1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create tables for all the above dataframes
temp_table_name = "janas"
asia_jan.createOrReplaceTempView(temp_table_name)

temp_table_name = "febas"
asia_feb.createOrReplaceTempView(temp_table_name)

temp_table_name = "marchas"
asia_mar.createOrReplaceTempView(temp_table_name)

temp_table_name = "aprilas"
asia_apr.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("select continent, month, sum(confirmed) as Infections from janas group by continent, month").show()
spark.sql("select continent, month, sum(confirmed) as Infections from febas group by continent, month").show()
spark.sql("select continent, month, sum(confirmed) as Infections from marchas group by continent, month").show()
spark.sql("select continent, month, sum(confirmed) as Infections from aprilas group by continent, month").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+----------+
# continent|month|Infections|
# +---------+-----+----------+
#      Asia|   01|      9868|
# +---------+-----+----------+
#
# +---------+-----+----------+
# continent|month|Infections|
# +---------+-----+----------+
#      Asia|   02|     80527|
# +---------+-----+----------+
#
# +---------+-----+----------+
# continent|month|Infections|
# +---------+-----+----------+
#      Asia|   03|    167008|
# +---------+-----+----------+
#
# +---------+-----+----------+
# continent|month|Infections|
# +---------+-----+----------+
#      Asia|   04|    503434|
# +---------+-----+----------+
#
# </div>

# %%
# Latitudes between 23.55 and 23.5 N are called the Tropics.
spark.sql("select * from covid limit 1").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-----------+----+----+---------+---------+------+---------+----------+
# province|    country| lat|long|     date|confirmed|deaths|recovered|  date_mod|
# +--------+-----------+----+----+---------+---------+------+---------+----------+
#     null|Afghanistan|33.0|65.0|1/22/2020|        0|     0|        0|2020-01-22|
# +--------+-----------+----+----+---------+---------+------+---------+----------+
#
# </div>

# %%
# Negative latitude is used to denote the regions south of the equator
tropical = spark.sql("select * from covid where lat between -23.5 and 23.55")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a dataframe for non tropical datasets
non_tropical = spark.sql("select * from covid where lat not between -23.5 and 23.55")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Since this is time series data, keeping only the latest observation for all countries as this represents the most recent reading 
tropical = tropical.filter("date_mod == '2020-04-30'")
non_tropical = non_tropical.filter("date_mod == '2020-04-30'")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create a new column in the dataframes to calculate mortality rate
tropical = tropical.withColumn("percentage", (F.col("deaths")/F.col("confirmed"))*100)
non_tropical = non_tropical.withColumn("percentage", (F.col("deaths")/F.col("confirmed"))*100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create tables for all the above dataframes
temp_table_name = "tropical"
tropical.createOrReplaceTempView(temp_table_name)

temp_table_name = "nontropical"
non_tropical.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Calculate the number of cases, deaths in tropical regions & non-tropical regions
spark.sql("select sum(confirmed) as InfectedInTropicalRegions, sum(deaths) as DeathsInTropical from tropical").show()
spark.sql("select sum(confirmed) as InfectedIn_NonTropicalRegions, sum(deaths) as DeathsinNonTropical from nontropical").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------------+----------------+
# InfectedInTropicalRegions|DeathsInTropical|
# +-------------------------+----------------+
#                    282032|           12312|
# +-------------------------+----------------+
#
# +-----------------------------+-------------------+
# InfectedIn_NonTropicalRegions|DeathsinNonTropical|
# +-----------------------------+-------------------+
#                       2974809|             221076|
# +-----------------------------+-------------------+
#
# </div>
